# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('datasets\House_Price_dataset.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18520\440288903.py:1: SyntaxWarning: invalid escape sequence '\H'
#   df = pd.read_csv('datasets\House_Price_dataset.csv')

# %%
df.head(7)
# Out:
#    property_id  location_id  \
# 0       237062         3325
# 1       346905         3236
# 2       386513          764
# 3       656161          340
# 4       841645         3226
# 5       850762         3390
# 6       937975          445
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
# 5  https://www.zameen.com/Property/ghauri_town_gh...         House  34500000
# 6  https://www.zameen.com/Property/islamabad_kora...         House  27000000
#
#       location       city      province_name   latitude  longitude  baths  \
# ...

# %%
summary_stats = df[['price','Area Size']].describe()
summary_stats
# Out:
#               price      Area Size
# count  1.684460e+05  168446.000000
# mean   1.776576e+07       5.892188
# std    3.531003e+07       5.778327
# min    0.000000e+00       0.000000
# 25%    1.750000e+05       3.000000
# 50%    8.500000e+06       5.000000
# 75%    1.950000e+07       8.000000
# max    2.000000e+09     800.000000

# %%
df['price_by_sqft'] = df['price'] / df['Area Size']

# %%
df.head(7)
# Out:
#    property_id  location_id  \
# 0       237062         3325
# 1       346905         3236
# 2       386513          764
# 3       656161          340
# 4       841645         3226
# 5       850762         3390
# 6       937975          445
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
# 5  https://www.zameen.com/Property/ghauri_town_gh...         House  34500000
# 6  https://www.zameen.com/Property/islamabad_kora...         House  27000000
#
#       location       city      province_name   latitude  longitude  ...  \
# ...

# %%
plt.scatter(df['Area Size'], df['price'], color='blue')
plt.title('Price vs sqft')
plt.show()
