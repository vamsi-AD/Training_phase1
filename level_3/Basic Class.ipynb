# %%
class Person:
    def __init__(self,name):
        self.name = name
        
    def greet(self):
        print(f"Hi, {self.name}")

# %%
alice = Person('Alice')
alice.greet()
# Out:
# Hi, Alice
