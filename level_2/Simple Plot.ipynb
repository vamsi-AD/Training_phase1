# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3]
y = [i*2 for i in x]

# %%
y
# Out:
# [2, 4, 6]

# %%
plt.plot(x,y,'b',marker = 'o',mfc = 'r',markersize = 10)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Simple Ploting by matplotlib")
# Out:
# Text(0.5, 1.0, 'Simple Ploting by matplotlib')
